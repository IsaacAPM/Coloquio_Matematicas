# %% [markdown]
# # Coloquio de Matemáticas
# ## Introducción a la Computación Cuántica
#
# ### Isaac Alejandro Pimentel Morales
#
# <div>
#
#
# <p style = 'text-align:center;'>
# <img src="./Imagenes/teleporte.png" alt="JuveYell">
# </p>
# </div>

# %% [markdown]
# # Mecánica Cuántica
#
# El conjunto de reglas que gobiernan el comportamiento de objetos tales como átomos, moléculas y luz.
#
# <div>
# <p style = 'text-align:center;'>
# <img src="./Imagenes/iones.png" alt="JuveYell">
# </p>
# </div>

# %% [markdown]
# # Dualidad Onda-Partícula
#
# **Propiedades de las ondas**: las ondas interactúan entre sí para formar patrones complejos en un proceso llamado **interferencia**.
#
# <div>
# <p style = 'text-align:center;'>
# <img src="./Imagenes/interferencia.png" alt="JuveYell">
# </p>
# </div>

# %% [markdown]
# **Propiedades de las partículas**: las partículas, como los balones de fútbol, tienen masa, tienen una **ubicación definida y discreta**, también viajan con cierta velocidad.
#
# <div>
# <p style = 'text-align:center;'>
# <img src="./Imagenes/particula.png" alt="JuveYell">
# </p>
# </div>

# %% [markdown]
# <div>
# <p style = 'text-align:center;'>
# <img src="./Imagenes/dobleRendija.png" alt="JuveYell">
# </p>
# </div>

# %% [markdown]
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/patronInterferencia.png" alt="JuveYell">
# </p>
# </div>

# %% [markdown]
# # Superposición
#
# Los objetos cuánticos pueden estar en una combinación de múltiples estados posibles. Por ejemplo, en un átomo, los electrones están en una superposición de muchas posiciones posibles.
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/single_electron_orbitals.jpg" alt="JuveYell" width="500px" align="center">
# </p>
# </div>

# %% [markdown]
# # ¿Qué es una computadora cuántica?
#
# Una computadora cuántica es un dispositivo que utiliza las propiedades de la mecánica cuántica para resolver problemas que las computadoras clásicas no pueden.
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/52751908_303.jpg" alt="JuveYell" align="center">
# </p>
# </div>

# %% [markdown]
# # Qubits
#
# Un qubit es la unidad fundamental de información en una computadora cuántica, al igual que un bit es la unidad fundamental de información en una computadora clásica. Mientras que los bits clásicos solo pueden ser 0 o 1, los qubits pueden ser 0, 1 o una combinación de estos estados.
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/bitsvsqubits.png" alt="JuveYell" align="center">
# </p>
# </div>

# %% [markdown]
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/qubits.png" alt="JuveYell" align="center">
# </p>
# </div>

# %% [markdown]
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/bloch.png" alt="JuveYell" align="center">
# </p>
# </div>

# %% [markdown]
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/masmenos.png" alt="JuveYell" align="center" >
# </p>
# </div>

# %% [markdown]
# # Circuitos Cuánticos
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/Modelocircuito.png" alt="JuveYell" align="center" >
# </p>
# </div>

# %%
from qiskit import QuantumCircuit, assemble, Aer
from qiskit.visualization import plot_histogram

# %%
qc = QuantumCircuit(1)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# # Compuerta X
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/x.png" alt="JuveYell" align="center" >
# </p>
# </div>

# %%
qc = QuantumCircuit(1)
qc.x(0)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# # Compuerta Hadamard
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/H.png" alt="JuveYell" align="center" >
# </p>
# </div>

# %%
qc = QuantumCircuit(1)
qc.h(0)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# # Entrelazamiento Cuántico
#
# Cuando consideramos la superposición de estados de dos partículas obtenemos el fenómeno conocido como entrelazamiento cuántico
#
# ## Sistemas de dos Qubits
#
# $$|00 \rangle$$
# $$|01 \rangle$$
# $$|11 \rangle$$
# $$|10 \rangle$$

# %%
qc = QuantumCircuit(2)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %%
qc = QuantumCircuit(2)
qc.x(1)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# # Compuerta CNOT
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/cnot.png" alt="JuveYell" align="center" >
# </p>
# </div>

# %%
qc = QuantumCircuit(2)
qc.cnot(0,1)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %%
qc = QuantumCircuit(2)
qc.x(0)
qc.cnot(0,1)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# # Creando entrelazamiento

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cnot(0,1)
qc.measure_all()
qc.draw('mpl',initial_state=True)

# %%
sim = Aer.get_backend('aer_simulator') 
result = sim.run(qc).result()
counts = result.get_counts()
plot_histogram(counts)

# %% [markdown]
# # Computadoras cuánticas actuales
#
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/ibmq.jpg" alt="JuveYell" align="center" >
# </p>
# </div>

# %% [markdown]
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/ejemplo.png" alt="JuveYell" align="center" >
# </p>
# </div>

# %% [markdown]
# <div align="center">
# <p style = 'text-align:center;'>
# <img src="./Imagenes/6015f860794e0d101cb26409_histogram.png" alt="JuveYell" align="center" >
# </p>
# </div>
